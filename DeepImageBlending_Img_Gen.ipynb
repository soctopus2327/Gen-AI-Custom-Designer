# %%
# !git clone https://github.com/owenzlz/DeepImageBlending.git
# Out:
# Cloning into 'DeepImageBlending'...
# remote: Enumerating objects: 249, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 249 (delta 26), reused 19 (delta 19), pack-reused 210
# Receiving objects: 100% (249/249), 43.58 MiB | 29.52 MiB/s, done.
# Resolving deltas: 100% (117/117), done.

# %%
# %mv /content/DeepImageBlending/pyproject.toml /content

# %%
# !pip install poetry
# !poetry install
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 24.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: keyring
#     Found existing installation: keyring 23.5.0
#     Uninstalling keyring-23.5.0:
#       Successfully uninstalled keyring-23.5.0
# ...

# %% [markdown]
# Make slight modifications to the run.py file.

# %%
# !poetry run python /content/DeepImageBlending/run.py
# Out:
# Streaming output truncated to the last 5000 lines.
#
# run [374]:
# grad : 23182.103516, style : 31202.890625, content: 7267.354980, tv: 5.291785
#
# run [375]:
# grad : 22504.195312, style : 30571.292969, content: 7192.927246, tv: 5.289582
#
# run [376]:
# grad : 22232.054688, style : 30124.271484, content: 7156.738770, tv: 5.288744
#
# run [377]:
# grad : 21971.746094, style : 29643.695312, content: 7107.939453, tv: 5.287602
#
# run [378]:
# grad : 21583.888672, style : 29245.593750, content: 7013.917969, tv: 5.285718
#
# run [379]:
# grad : 21401.615234, style : 28447.992188, content: 6967.370605, tv: 5.284290
#
# run [380]:
# grad : 21201.830078, style : 28144.855469, content: 6921.832031, tv: 5.283387
#
# run [381]:
# grad : 20803.566406, style : 27801.650391, content: 6892.351562, tv: 5.282352
#
# run [382]:
# grad : 20453.218750, style : 27446.582031, content: 6844.447266, tv: 5.281103
#
# run [383]:
# ...
